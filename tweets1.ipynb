# %% [markdown]
# <a href="https://colab.research.google.com/github/AliArabi55/Algorithim-Task/blob/main/tweets1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/tweets1.csv')
df.head()
# Out:
#                User                                              Tweet  \
# 0       @alydesigns  i was out most of the day so didn't get much done
# 1  @FakerPattyPattz  Oh dear. Were you drinking out of the forgotte...
# 2           @LettyA  ahh ive always wanted to see rent love the sou...
#
#     DateTime
# 0  12/3/2004
# 1  2/15/2018
# 2   3/1/2009

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'], format='%m/%d/%y')

# %%
df['Year'] = df['DateTime'].dt.year

# %%
df['Year']
# Out:
# 0    2004
# 1    2018
# 2    2009
# Name: Year, dtype: int32

# %%
df ['month'] =df['DateTime'].dt.month_name()

# %%
df ['month']
# Out:
# 0    December
# 1    February
# 2       March
# Name: month, dtype: object

# %%
df ['day'] =df['DateTime'].dt.day_name()

# %%
df ['day']
# Out:
# 0      Friday
# 1    Thursday
# 2      Sunday
# Name: day, dtype: object

# %%
df
# Out:
#                User                                              Tweet  \
# 0       @alydesigns  i was out most of the day so didn't get much done
# 1  @FakerPattyPattz  Oh dear. Were you drinking out of the forgotte...
# 2           @LettyA  ahh ive always wanted to see rent love the sou...
#
#     DateTime  Year  month       day
# 0 2004-12-03  2004     12    Friday
# 1 2018-02-15  2018      2  Thursday
# 2 2009-03-01  2009      3    Sunday

# %%
print (df)
# Out:
#                User                                              Tweet  \
# 0       @alydesigns  i was out most of the day so didn't get much done
# 1  @FakerPattyPattz  Oh dear. Were you drinking out of the forgotte...
# 2           @LettyA  ahh ive always wanted to see rent love the sou...
#
#     DateTime  Year  month       day
# 0 2004-12-03  2004     12    Friday
# 1 2018-02-15  2018      2  Thursday
# 2 2009-03-01  2009      3    Sunday

# %%
df = pd.read_csv('/content/tweets.csv')
df.head()
# Out:
#                User                                              Tweet  \
# 0       @alydesigns  i was out most of the day so didn't get much done
# 1  @FakerPattyPattz  Oh dear. Were you drinking out of the forgotte...
# 2           @LettyA  ahh ive always wanted to see rent love the sou...
#
#           DateTime
# 0  12/3/2004 15:08
# 1  2/15/2018 23:17
# 2    3/1/2009 3:10

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'], format='%m/%d/%y %H:%M:%S')

# %%
df['DateTime']
# Out:
# 0   2004-12-03 15:08:00
# 1   2018-02-15 23:17:00
# 2   2009-03-01 03:10:00
# Name: DateTime, dtype: datetime64[ns]

# %%
df['hour'] = df['DateTime'].dt.hour
df['min'] = df['DateTime'].dt.minute
df['sec'] = df['DateTime'].dt.second

# %%
df.head()
# Out:
#                User                                              Tweet  \
# 0       @alydesigns  i was out most of the day so didn't get much done
# 1  @FakerPattyPattz  Oh dear. Were you drinking out of the forgotte...
# 2           @LettyA  ahh ive always wanted to see rent love the sou...
#
#              DateTime  hour  min  sec
# 0 2004-12-03 15:08:00    15    8    0
# 1 2018-02-15 23:17:00    23   17    0
# 2 2009-03-01 03:10:00     3   10    0

# %%
print (df)
# Out:
#                User                                              Tweet  \
# 0       @alydesigns  i was out most of the day so didn't get much done
# 1  @FakerPattyPattz  Oh dear. Were you drinking out of the forgotte...
# 2           @LettyA  ahh ive always wanted to see rent love the sou...
#
#              DateTime  hour  min  sec
# 0 2004-12-03 15:08:00    15    8    0
# 1 2018-02-15 23:17:00    23   17    0
# 2 2009-03-01 03:10:00     3   10    0
